# %% [markdown]
# <a href="https://colab.research.google.com/github/api-sage/numpy_classes/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sys

a = np.array([[1,2,3],[4,5,6]])
b = np.array([4,5,6])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]
